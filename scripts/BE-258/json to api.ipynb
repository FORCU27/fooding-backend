# %%
import json
import requests
import time
from typing import Dict, List, Any
import os

# %%
def load_restaurant_data(json_file_path: str) -> List[Dict[str, Any]]:
    """
    JSON 파일에서 레스토랑 데이터를 로드합니다.
    
    Args:
        json_file_path: JSON 파일 경로
        
    Returns:
        레스토랑 리스트
    """
    with open(json_file_path, 'r', encoding='utf-8') as file:
        data = json.load(file)
        return data.get('restaurants', [])

# %%
def format_restaurant_for_api(restaurant: Dict[str, Any]) -> Dict[str, Any]:
    """
    레스토랑 데이터를 API 요청 형식으로 변환합니다.
    
    Args:
        restaurant: 원본 레스토랑 데이터
        
    Returns:
        API 요청용 포맷된 데이터
    """
    # 메뉴 데이터 변환 (price_text 제거, price만 유지)
    formatted_menus = []
    for menu in restaurant.get('menus', []):
        if menu.get('name') and menu.get('price') is not None:
            formatted_menus.append({
                'name': menu['name'],
                'price': menu['price']
            })
    
    return {
        'id': restaurant.get('place_id', ''),
        'name': restaurant.get('name', ''),
        'category': restaurant.get('category', ''),
        'address': restaurant.get('address', ''),
        'contact': restaurant.get('contact', ''),
        'menus': formatted_menus
    }

# %%
def send_restaurant_to_api(restaurant_data: Dict[str, Any], api_url: str = "http://localhost:8080/crawling/naver-places") -> bool:
    """
    레스토랑 데이터를 API로 전송합니다.
    
    Args:
        restaurant_data: API로 전송할 레스토랑 데이터
        api_url: API 엔드포인트 URL
        
    Returns:
        성공 여부 (True/False)
    """
    try:
        headers = {
            'Content-Type': 'application/json',
            'Accept': 'application/json'
        }
        
        response = requests.post(
            api_url,
            json=restaurant_data,
            headers=headers,
            timeout=30
        )
        
        if response.status_code == 200:
            print(f"✅ 성공: {restaurant_data['name']}")
            return True
        else:
            print(f"❌ 실패: {restaurant_data['name']} - Status: {response.status_code}")
            print(f"   응답: {response.text}")
            return False
            
    except requests.exceptions.RequestException as e:
        print(f"❌ 요청 에러: {restaurant_data['name']} - {str(e)}")
        return False
    except Exception as e:
        print(f"❌ 일반 에러: {restaurant_data['name']} - {str(e)}")
        return False

# %%
def process_restaurants_to_api(json_file_path: str, api_url: str = "http://localhost:8080/crawling/naver-places", delay: float = 0.5):
    """
    JSON 파일의 모든 레스토랑을 API로 전송합니다.
    
    Args:
        json_file_path: JSON 파일 경로
        api_url: API 엔드포인트 URL
        delay: 요청 간 대기 시간 (초)
    """
    print(f"📄 JSON 파일 로딩 중: {json_file_path}")
    
    # JSON 파일 로드
    restaurants = load_restaurant_data(json_file_path)
    total_restaurants = len(restaurants)
    
    print(f"📊 총 {total_restaurants}개의 레스토랑 발견")
    print(f"🎯 API 엔드포인트: {api_url}")
    print("=" * 50)
    
    success_count = 0
    failure_count = 0
    
    for i, restaurant in enumerate(restaurants, 1):
        print(f"\n[{i}/{total_restaurants}] 처리 중...")
        
        # API 형식으로 변환
        formatted_data = format_restaurant_for_api(restaurant)
        
        # 메뉴가 없는 레스토랑 스킵
        if not formatted_data['menus']:
            print(f"⚠️  스킵: {formatted_data['name']} - 메뉴 정보 없음")
            continue
        
        # API로 전송
        if send_restaurant_to_api(formatted_data, api_url):
            success_count += 1
        else:
            failure_count += 1
        
        # 요청 간 대기
        if delay > 0:
            time.sleep(delay)
    
    print("\n" + "=" * 50)
    print(f"📈 전송 완료!")
    print(f"✅ 성공: {success_count}개")
    print(f"❌ 실패: {failure_count}개")
    print(f"📊 성공률: {success_count/(success_count+failure_count)*100:.1f}%" if (success_count+failure_count) > 0 else "0%")

# %%
# 실행 설정
JSON_FILE_PATH = "./naver_restaurants_20250813_153837.json"  # 또는 "./naver_restaurants_20250812_012556.json"
API_URL = "http://localhost:8080/crawling/naver-places"
DELAY_BETWEEN_REQUESTS = 0.5  # 0.5초 대기

# 파일 존재 확인
if os.path.exists(JSON_FILE_PATH):
    print(f"✅ JSON 파일 확인됨: {JSON_FILE_PATH}")
else:
    print(f"❌ JSON 파일을 찾을 수 없습니다: {JSON_FILE_PATH}")
    print("현재 디렉토리의 파일들:")
    for file in os.listdir('.'):
        if file.endswith('.json'):
            print(f"  📄 {file}")
# Out:
# ✅ JSON 파일 확인됨: ./naver_restaurants_20250813_153837.json

# %%
# 테스트: 첫 번째 레스토랑만 전송해보기
def test_single_restaurant(json_file_path: str):
    """
    첫 번째 레스토랑만 테스트로 전송합니다.
    """
    restaurants = load_restaurant_data(json_file_path)
    
    if not restaurants:
        print("❌ 레스토랑 데이터가 없습니다.")
        return
    
    # 메뉴가 있는 첫 번째 레스토랑 찾기
    test_restaurant = None
    for restaurant in restaurants:
        if restaurant.get('menus') and len(restaurant['menus']) > 0:
            # None 가격인 메뉴 제외하고 유효한 메뉴가 있는지 확인
            valid_menus = [m for m in restaurant['menus'] if m.get('price') is not None]
            if valid_menus:
                test_restaurant = restaurant
                break
    
    if not test_restaurant:
        print("❌ 유효한 메뉴가 있는 레스토랑을 찾을 수 없습니다.")
        return
    
    print(f"🧪 테스트 레스토랑: {test_restaurant['name']}")
    print(f"📍 주소: {test_restaurant.get('address', 'N/A')}")
    print(f"🍽️  메뉴 수: {len([m for m in test_restaurant['menus'] if m.get('price') is not None])}개")
    
    # API 형식으로 변환
    formatted_data = format_restaurant_for_api(test_restaurant)
    
    print(f"\n📤 API 요청 데이터:")
    print(json.dumps(formatted_data, ensure_ascii=False, indent=2))
    
    # API로 전송
    print(f"\n🚀 API 전송 중...")
    success = send_restaurant_to_api(formatted_data)
    
    return success

# 테스트 실행 (주석 해제하여 실행)
# test_single_restaurant(JSON_FILE_PATH)

# %%
# 전체 레스토랑 API 전송 실행
# ⚠️ 주의: 실행 전에 API 서버가 실행 중인지 확인하세요!

def main():
    """
    메인 실행 함수
    """
    print("🍽️  네이버 플레이스 레스토랑 → API 전송 시작")
    print("=" * 60)
    
    # 1. 단일 테스트 먼저 실행
    print("1️⃣ 단일 레스토랑 테스트 중...")
    test_success = test_single_restaurant(JSON_FILE_PATH)
    
    if not test_success:
        print("❌ 테스트 실패! API 서버 상태를 확인하세요.")
        return
    
    print("\n✅ 테스트 성공! 전체 배치 처리를 시작합니다.")
    
    # 사용자 확인
    response = input("\n계속 진행하시겠습니까? (y/N): ")
    if response.lower() != 'y':
        print("🛑 처리를 중단합니다.")
        return
    
    # 2. 전체 배치 처리
    print("\n2️⃣ 전체 레스토랑 배치 처리 중...")
    process_restaurants_to_api(
        json_file_path=JSON_FILE_PATH,
        api_url=API_URL,
        delay=DELAY_BETWEEN_REQUESTS
    )
    
    print("\n🎉 모든 처리가 완료되었습니다!")

# 실행 (주석 해제하여 실행)
# main()

# %%
# 🎯 사용 방법 가이드
"""
📋 실행 순서:

1. 먼저 모든 셀을 순서대로 실행하여 함수들을 로드합니다.

2. JSON 파일 경로를 확인합니다:
   - JSON_FILE_PATH 변수에서 원하는 파일을 선택
   - 두 개 파일 중 선택 가능:
     * naver_restaurants_20250812_012556.json (127개 레스토랑)
     * naver_restaurants_20250812_130001.json (52개 레스토랑)

3. API 서버가 실행 중인지 확인합니다:
   - http://localhost:8080 에서 서버 실행 필요

4. 테스트 실행:
   test_single_restaurant(JSON_FILE_PATH)

5. 전체 실행:
   main()

🔧 설정 옵션:
- DELAY_BETWEEN_REQUESTS: 요청 간 대기 시간 조정
- API_URL: API 엔드포인트 변경 가능
"""

# 추가 유틸리티: 특정 레스토랑만 전송
def send_specific_restaurants(json_file_path: str, restaurant_names: List[str]):
    """
    특정 이름의 레스토랑들만 API로 전송합니다.
    
    Args:
        json_file_path: JSON 파일 경로
        restaurant_names: 전송할 레스토랑 이름 리스트
    """
    restaurants = load_restaurant_data(json_file_path)
    
    found_restaurants = []
    for restaurant in restaurants:
        if restaurant.get('name') in restaurant_names:
            found_restaurants.append(restaurant)
    
    print(f"📊 찾은 레스토랑: {len(found_restaurants)}/{len(restaurant_names)}개")
    
    for restaurant in found_restaurants:
        formatted_data = format_restaurant_for_api(restaurant)
        if formatted_data['menus']:
            send_restaurant_to_api(formatted_data)
        else:
            print(f"⚠️  스킵: {restaurant['name']} - 메뉴 없음")

# 예시 사용법:
# send_specific_restaurants(JSON_FILE_PATH, ["자연산 해담일식 대게마을", "멕시타이거"])

# %%
# 테스트 실행 - 단일 레스토랑 확인
print("🧪 단일 레스토랑 테스트 실행 중...")
test_single_restaurant(JSON_FILE_PATH)
# Out:
# 🧪 단일 레스토랑 테스트 실행 중...
# 🧪 테스트 레스토랑: 멕시타이거
# 📍 주소: 서울 강남구 테헤란로1길 42 B1층 1호
# 🍽️  메뉴 수: 41개
#
# 📤 API 요청 데이터:
# {
#   "id": "1486617466",
#   "name": "멕시타이거",
#   "category": "요리주점",
#   "address": "서울 강남구 테헤란로1길 42 B1층 1호",
#   "contact": "0507-1425-9866",
#   "menus": [
#     {
#       "name": "지미추리 화덕치킨",
#       "price": 21900
#     },
#     {
#       "name": "하바네로 화덕치킨",
#       "price": 21900
#     },
#     {
#       "name": "타이거새우 버터몰레",
#       "price": 25900
#     },
#     {
#       "name": "버터몰레 플레이트",
#       "price": 13900
#     },
#     {
#       "name": "비리얌 라멘",
#       "price": 13900
#     },
#     {
#       "name": "치폴레 퀘사디아",
#       "price": 19900
#     },
#     {
#       "name": "망고 세비체",
#       "price": 7900
#     },
#     {
#       "name": "지미추리 치킨몰레",
#       "price": 55700
#     },
#     {
#       "name": "하바네로 치킨몰레",
#       "price": 55700
#     },
#     {
#       "name": "빠빠스",
#       "price": 13900
#     },
#     {
#       "name": "치폴레몰레 플레이트",
#       "price": 13900
#     },
#     {
#       "name": "피쉬 타코",
#       "price": 18900
#     },
#     {
#       "name": "호세 데낄라 하이볼",
#       "price": 7900
#     },
#     {
#       "name": "라구몰레 나초플래터",
#       "price": 15900
#     },
#     {
#       "name": "라임 데낄라 하이볼",
#       "price": 6900
#     },
#     {
#       "name": "당근 데낄라 세트",
#       "price": 18900
#     },
#     {
#       "name": "멕시타이거 하우스 데낄라",
#       "price": 33000
#     },
#     {
#       "name": "데낄라 썬라이즈",
#       "price": 7900
#     },
#     {
#       "name": "데낄라 라임 하이볼",
#       "price": 7900
#     },
#     {
#       "name": "블루 마가리따",
#       "price": 9900
#     },
#     {
#       "name": "슬래머 세트",
#       "price": 17400
#     },
#     {
#       "name": "핑크 슬래머 세트",
#       "price": 17400
#     },
#     {
#       "name": "갈릭 퀘사디야",
#       "price": 19900
#     },
#     {
#       "name": "치즈 퀘사디아",
#       "price": 19900
#     },
#     {
#       "name": "치즈몰레 나초플래터",
#       "price": 15900
#     },
#     {
#       "name": "과카몰레 나초플래터",
#       "price": 15900
#     },
#     {
#       "name": "멕시칸 칠리크랩",
#       "price": 20900
#     },
#     {
#       "name": "멕시칸 콘립",
#       "price": 11900
#     },
#     {
#       "name": "치폴레 고추튀김",
#       "price": 13900
#     },
#     {
#       "name": "깐풍가지",
#       "price": 12900
#     },
#     {
#       "name": "홍유 물만두",
#       "price": 13900
#     },
#     {
#       "name": "트러플 버터오징어",
#       "price": 16900
#     },
#     {
#       "name": "토마토 홍합스튜",
#       "price": 16900
#     },
#     {
#       "name": "새우 세비체",
#       "price": 9900
#     },
#     {
#       "name": "망고 젤라또",
#       "price": 7900
#     },
#     {
#       "name": "트러플바닐라 젤라또",
#       "price": 8900
#     },
#     {
#       "name": "데낄라 샷세트",
#       "price": 17400
#     },
#     {
#       "name": "멕시타이거 라거",
#       "price": 5900
#     },
#     {
#       "name": "페일에일",
#       "price": 6900
#     },
#     {
#       "name": "IPA",
#       "price": 7900
#     },
#     {
#       "name": "임페리얼 스타우트",
#       "price": 9900
#     }
#   ]
# }
#
# 🚀 API 전송 중...
# ✅ 성공: 멕시타이거
# True

# %%
# 🚀 전체 레스토랑 API 전송 실행
# ⚠️ 주의: 아래 주석을 해제하고 실행하면 모든 레스토랑이 API로 전송됩니다!

main()

print("📋 전체 실행을 원하시면 위의 main() 주석을 해제하고 실행하세요.")
print(f"📊 현재 JSON 파일: {JSON_FILE_PATH}")
print(f"🎯 API 엔드포인트: {API_URL}")

# 또는 특정 레스토랑만 전송하고 싶다면:
# send_specific_restaurants(JSON_FILE_PATH, ["자연산 해담일식 대게마을", "강삼가든"])
# Out:
# 🍽️  네이버 플레이스 레스토랑 → API 전송 시작
# ============================================================
# 1️⃣ 단일 레스토랑 테스트 중...
# 🧪 테스트 레스토랑: 멕시타이거
# 📍 주소: 서울 강남구 테헤란로1길 42 B1층 1호
# 🍽️  메뉴 수: 41개
#
# 📤 API 요청 데이터:
# {
#   "id": "1486617466",
#   "name": "멕시타이거",
#   "category": "요리주점",
#   "address": "서울 강남구 테헤란로1길 42 B1층 1호",
#   "contact": "0507-1425-9866",
#   "menus": [
#     {
#       "name": "지미추리 화덕치킨",
#       "price": 21900
#     },
#     {
#       "name": "하바네로 화덕치킨",
#       "price": 21900
#     },
#     {
#       "name": "타이거새우 버터몰레",
#       "price": 25900
#     },
#     {
#       "name": "버터몰레 플레이트",
#       "price": 13900
#     },
#     {
#       "name": "비리얌 라멘",
#       "price": 13900
#     },
#     {
#       "name": "치폴레 퀘사디아",
#       "price": 19900
#     },
#     {
#       "name": "망고 세비체",
#       "price": 7900
#     },
#     {
#       "name": "지미추리 치킨몰레",
#       "price": 55700
#     },
#     {
#       "name": "하바네로 치킨몰레",
#       "price": 55700
#     },
#     {
#       "name": "빠빠스",
#       "price": 13900
#     },
#     {
#       "name": "치폴레몰레 플레이트",
#       "price": 13900
#     },
#     {
#       "name": "피쉬 타코",
#       "price": 18900
#     },
#     {
#       "name": "호세 데낄라 하이볼",
#       "price": 7900
#     },
#     {
#       "name": "라구몰레 나초플래터",
#       "price": 15900
#     },
#     {
#       "name": "라임 데낄라 하이볼",
#       "price": 6900
#     },
#     {
#       "name": "당근 데낄라 세트",
#       "price": 18900
#     },
#     {
#       "name": "멕시타이거 하우스 데낄라",
#       "price": 33000
#     },
#     {
#       "name": "데낄라 썬라이즈",
#       "price": 7900
#     },
#     {
#       "name": "데낄라 라임 하이볼",
#       "price": 7900
#     },
#     {
#       "name": "블루 마가리따",
#       "price": 9900
#     },
#     {
#       "name": "슬래머 세트",
#       "price": 17400
#     },
#     {
#       "name": "핑크 슬래머 세트",
#       "price": 17400
#     },
#     {
#       "name": "갈릭 퀘사디야",
#       "price": 19900
#     },
#     {
#       "name": "치즈 퀘사디아",
#       "price": 19900
#     },
#     {
#       "name": "치즈몰레 나초플래터",
#       "price": 15900
#     },
#     {
#       "name": "과카몰레 나초플래터",
#       "price": 15900
#     },
#     {
#       "name": "멕시칸 칠리크랩",
#       "price": 20900
#     },
#     {
#       "name": "멕시칸 콘립",
#       "price": 11900
#     },
#     {
#       "name": "치폴레 고추튀김",
#       "price": 13900
#     },
#     {
#       "name": "깐풍가지",
#       "price": 12900
#     },
#     {
#       "name": "홍유 물만두",
#       "price": 13900
#     },
#     {
#       "name": "트러플 버터오징어",
#       "price": 16900
#     },
#     {
#       "name": "토마토 홍합스튜",
#       "price": 16900
#     },
#     {
#       "name": "새우 세비체",
#       "price": 9900
#     },
#     {
#       "name": "망고 젤라또",
#       "price": 7900
#     },
#     {
#       "name": "트러플바닐라 젤라또",
#       "price": 8900
#     },
#     {
#       "name": "데낄라 샷세트",
#       "price": 17400
#     },
#     {
#       "name": "멕시타이거 라거",
#       "price": 5900
#     },
#     {
#       "name": "페일에일",
#       "price": 6900
#     },
#     {
#       "name": "IPA",
#       "price": 7900
#     },
#     {
#       "name": "임페리얼 스타우트",
#       "price": 9900
#     }
#   ]
# }
#
# 🚀 API 전송 중...
# ✅ 성공: 멕시타이거
#
# ✅ 테스트 성공! 전체 배치 처리를 시작합니다.
#
# 2️⃣ 전체 레스토랑 배치 처리 중...
# 📄 JSON 파일 로딩 중: ./naver_restaurants_20250813_153837.json
# 📊 총 142개의 레스토랑 발견
# 🎯 API 엔드포인트: http://localhost:8080/crawling/naver-places
# ==================================================
#
# [1/142] 처리 중...
# ✅ 성공: 멕시타이거
#
# [2/142] 처리 중...
# ✅ 성공: 쿄코코 신논현점
#
# [3/142] 처리 중...
# ✅ 성공: 빨간의자집 강남역점
#
# [4/142] 처리 중...
# ✅ 성공: 장인닭갈비 강남점
#
# [5/142] 처리 중...
# ✅ 성공: 소보키 강남점
#
# [6/142] 처리 중...
# ⚠️  스킵: 다운타우너 강남 - 메뉴 정보 없음
#
# [7/142] 처리 중...
# ✅ 성공: 오봉집 신논현점
#
# [8/142] 처리 중...
# ✅ 성공: 미나리밭오리사냥 강남역점
#
# [9/142] 처리 중...
# ✅ 성공: 클로즈키친
#
# [10/142] 처리 중...
# ✅ 성공: 코제트 도산
#
# [11/142] 처리 중...
# ✅ 성공: 멜로우가든 강남점
#
# [12/142] 처리 중...
# ✅ 성공: 서래향 수서점
#
# [13/142] 처리 중...
# ✅ 성공: 김이정 숯불구이 삼성본점
#
# [14/142] 처리 중...
# ✅ 성공: 감성타코 강남역점
#
# [15/142] 처리 중...
# ✅ 성공: 이치서울
#
# [16/142] 처리 중...
# ✅ 성공: 역전포장마차 강남
#
# [17/142] 처리 중...
# ✅ 성공: 치스타리에 강남역점
#
# [18/142] 처리 중...
# ✅ 성공: 진밀옥 본점
#
# [19/142] 처리 중...
# ✅ 성공: 가포 대치본점
#
# [20/142] 처리 중...
# ⚠️  스킵: 다운타우너 청담 - 메뉴 정보 없음
#
# [21/142] 처리 중...
# ✅ 성공: 다몽집 신논현본점
#
# [22/142] 처리 중...
# ✅ 성공: 후추포인트
#
# [23/142] 처리 중...
# ✅ 성공: 멘츠루 신사점
#
# [24/142] 처리 중...
# ✅ 성공: 뱅뱅막국수
#
# [25/142] 처리 중...
# ✅ 성공: 정돈 강남점
#
# [26/142] 처리 중...
# ✅ 성공: 까치화방 강남역점
#
# [27/142] 처리 중...
# ✅ 성공: 퍼스트커피랩 강남점
#
# [28/142] 처리 중...
# ✅ 성공: 고기꾼김춘배 강남점
#
# [29/142] 처리 중...
# ✅ 성공: 으뜸스시 신사직영점
#
# [30/142] 처리 중...
# ✅ 성공: 바샤커피 청담 플래그십 스토어
#
# [31/142] 처리 중...
# ✅ 성공: 구테로이테 본점
#
# [32/142] 처리 중...
# ⚠️  스킵: Workshop by 배스킨라빈스 - 메뉴 정보 없음
#
# [33/142] 처리 중...
# ✅ 성공: 도시맥주 신사가로수길본점
#
# [34/142] 처리 중...
# ✅ 성공: 빠레뜨한남 수서역점
#
# [35/142] 처리 중...
# ✅ 성공: 정돈 신사점
#
# [36/142] 처리 중...
# ✅ 성공: 선릉 우와해
#
# [37/142] 처리 중...
# ⚠️  스킵: 데일리픽스 강남본점 - 메뉴 정보 없음
#
# [38/142] 처리 중...
# ⚠️  스킵: 강남 곱 - 메뉴 정보 없음
#
# [39/142] 처리 중...
# ✅ 성공: 이비티 코엑스점
#
# [40/142] 처리 중...
# ⚠️  스킵: 닭가대표 숯불직화구이치킨 강남역삼대표점 - 메뉴 정보 없음
#
# [41/142] 처리 중...
# ✅ 성공: 신사만장어
#
# [42/142] 처리 중...
# ✅ 성공: 도치피자 강남
#
# [43/142] 처리 중...
# ✅ 성공: 신도세기 도곡직영점
#
# [44/142] 처리 중...
# ✅ 성공: 무탄 압구정 본점
#
# [45/142] 처리 중...
# ⚠️  스킵: 갓잇 도곡점 - 메뉴 정보 없음
#
# [46/142] 처리 중...
# ✅ 성공: 그랜드 인터컨티넨탈 서울 파르나스 그랜드 키친
#
# [47/142] 처리 중...
# ✅ 성공: 스시이찌 선릉점
#
# [48/142] 처리 중...
# ✅ 성공: 봉밀가 강남구청점
#
# [49/142] 처리 중...
# ✅ 성공: 몽갈비
#
# [50/142] 처리 중...
# ✅ 성공: 단성무이 강남점
#
# [51/142] 처리 중...
# ✅ 성공: 로마옥 도곡
#
# [52/142] 처리 중...
# ✅ 성공: 꽃새우 영번지 역삼점
#
# [53/142] 처리 중...
# ✅ 성공: 광화문석갈비 코엑스점
#
# [54/142] 처리 중...
# ✅ 성공: 오봉집 강남역점
#
# [55/142] 처리 중...
# ✅ 성공: 한성칼국수 논현본점
#
# [56/142] 처리 중...
# ✅ 성공: 우리소 삼성점
#
# [57/142] 처리 중...
# ✅ 성공: 소각
#
# [58/142] 처리 중...
# ✅ 성공: 마노디셰프 삼성점
#
# [59/142] 처리 중...
# ❌ 실패: 한사발포차 논현점 - Status: 400
#    응답: {"timestamp":"2025-08-13T16:03:20.361788","status":400,"code":"0004","message":"잘못된 파라미터 요청입니다.","url":"http://localhost:8080/crawling/naver-places","method":"POST","detailedErrors":[{"location":"contact","message":"공백일 수 없습니다"}]}
#
# [60/142] 처리 중...
# ✅ 성공: 모스가든
#
# [61/142] 처리 중...
# ✅ 성공: 우살롱 압구정점
#
# [62/142] 처리 중...
# ✅ 성공: 1992 덮밥&짜글이 강남본점
#
# [63/142] 처리 중...
# ⚠️  스킵: 가마쿠라 도산점 - 메뉴 정보 없음
#
# [64/142] 처리 중...
# ❌ 실패: 남소관 우육도삭면 - Status: 400
#    응답: {"timestamp":"2025-08-13T16:03:22.450423","status":400,"code":"0004","message":"잘못된 파라미터 요청입니다.","url":"http://localhost:8080/crawling/naver-places","method":"POST","detailedErrors":[{"location":"contact","message":"공백일 수 없습니다"}]}
#
# [65/142] 처리 중...
# ✅ 성공: 머무를 정 세이로무시 선릉점
#
# [66/142] 처리 중...
# ✅ 성공: 애월식당 압구정점
#
# [67/142] 처리 중...
# ✅ 성공: 텟어텟
#
# [68/142] 처리 중...
# ✅ 성공: 허머스키친
#
# [69/142] 처리 중...
# ✅ 성공: 바오로흑염소 선릉점
#
# [70/142] 처리 중...
# ✅ 성공: 호호식당 스타필드코엑스
#
# [71/142] 처리 중...
# ✅ 성공: 이대성의진면목 본점
#
# [72/142] 처리 중...
# ✅ 성공: 수목금토 카페
#
# [73/142] 처리 중...
# ⚠️  스킵: 핫쵸 가로수길 본점 - 메뉴 정보 없음
#
# [74/142] 처리 중...
# ✅ 성공: 루위
#
# [75/142] 처리 중...
# ✅ 성공: 대봉집 신사본점
#
# [76/142] 처리 중...
# ✅ 성공: 육미당 몽산
#
# [77/142] 처리 중...
# ✅ 성공: 스케줄청담
#
# [78/142] 처리 중...
# ✅ 성공: 우동명가기리야마본진
#
# [79/142] 처리 중...
# ✅ 성공: 더타코부스 압구정 본점
#
# [80/142] 처리 중...
# ✅ 성공: 도른계 강남역점
#
# [81/142] 처리 중...
# ✅ 성공: 베르체 도심공항터미널점
#
# [82/142] 처리 중...
# ✅ 성공: 을밀대 강남점
#
# [83/142] 처리 중...
# ✅ 성공: 데블스도어 코엑스점
#
# [84/142] 처리 중...
# ⚠️  스킵: 상무초밥 강남점 - 메뉴 정보 없음
#
# [85/142] 처리 중...
# ✅ 성공: 레자미오네뜨
#
# [86/142] 처리 중...
# ⚠️  스킵: 스미식당 수서역점 - 메뉴 정보 없음
#
# [87/142] 처리 중...
# ✅ 성공: 청와옥 본사직영학동점
#
# [88/142] 처리 중...
# ✅ 성공: 녘
#
# [89/142] 처리 중...
# ✅ 성공: 퍼시픽 스탠다드
#
# [90/142] 처리 중...
# ✅ 성공: 덤브치킨 한티역점
#
# [91/142] 처리 중...
# ✅ 성공: 직화장인 신사점
#
# [92/142] 처리 중...
# ✅ 성공: 강삼가든
#
# [93/142] 처리 중...
# ✅ 성공: 샤브로21 강남
#
# [94/142] 처리 중...
# ✅ 성공: 헤비스테이크 강남역점
#
# [95/142] 처리 중...
# ✅ 성공: 양인환대
#
# [96/142] 처리 중...
# ✅ 성공: 팡뮤제 베이커리 강남본점
#
# [97/142] 처리 중...
# ✅ 성공: 팔도밀방 강남본점
#
# [98/142] 처리 중...
# ✅ 성공: 부대찌개대사관 선릉직영점
#
# [99/142] 처리 중...
# ⚠️  스킵: 라폰다 - 메뉴 정보 없음
#
# [100/142] 처리 중...
# ✅ 성공: 쇼미더크랩 압구정점
#
# [101/142] 처리 중...
# ✅ 성공: 압구정 오렌지포차 술집
#
# [102/142] 처리 중...
# ✅ 성공: 라브리크 서울
#
# [103/142] 처리 중...
# ✅ 성공: 팔당족발
#
# [104/142] 처리 중...
# ✅ 성공: 미미포차
#
# [105/142] 처리 중...
# ✅ 성공: 김태완스시 대치본점
#
# [106/142] 처리 중...
# ✅ 성공: 청초수물회 강남점
#
# [107/142] 처리 중...
# ⚠️  스킵: 중화백반 강남구청점 - 메뉴 정보 없음
#
# [108/142] 처리 중...
# ✅ 성공: 압구정제주집
#
# [109/142] 처리 중...
# ✅ 성공: 태수
#
# [110/142] 처리 중...
# ✅ 성공: 우화
#
# [111/142] 처리 중...
# ✅ 성공: 우리집만두 선릉본점
#
# [112/142] 처리 중...
# ✅ 성공: 오또상라멘
#
# [113/142] 처리 중...
# ✅ 성공: 코메 압구정로데오
#
# [114/142] 처리 중...
# ✅ 성공: 보노보노 삼성점
#
# [115/142] 처리 중...
# ✅ 성공: 온심옥 역삼본점
#
# [116/142] 처리 중...
# ✅ 성공: 우주옥
#
# [117/142] 처리 중...
# ✅ 성공: 크라프트카페
#
# [118/142] 처리 중...
# ⚠️  스킵: 동대문원닭한마리 - 메뉴 정보 없음
#
# [119/142] 처리 중...
# ✅ 성공: 투아투아
#
# [120/142] 처리 중...
# ✅ 성공: 용용선생 논현점
#
# [121/142] 처리 중...
# ✅ 성공: 롱씨암
#
# [122/142] 처리 중...
# ✅ 성공: 우미학 압구정 본점
#
# [123/142] 처리 중...
# ✅ 성공: 골드피쉬 딤섬퀴진
#
# [124/142] 처리 중...
# ✅ 성공: 마초스테이크 본점
#
# [125/142] 처리 중...
# ⚠️  스킵: 도산분식 도산공원점 - 메뉴 정보 없음
#
# [126/142] 처리 중...
# ✅ 성공: 따우전드 신사점
#
# [127/142] 처리 중...
# ✅ 성공: 공리
#
# [128/142] 처리 중...
# ✅ 성공: 서울깍두기 강남역삼점
#
# [129/142] 처리 중...
# ✅ 성공: 파크 하얏트 서울 코너스톤
#
# [130/142] 처리 중...
# ✅ 성공: 팔당닭발 강남본점
#
# [131/142] 처리 중...
# ⚠️  스킵: 바비레드 강남본점 - 메뉴 정보 없음
#
# [132/142] 처리 중...
# ✅ 성공: 청담 마코토
#
# [133/142] 처리 중...
# ❌ 실패: 갓포우오 신사점 - Status: 400
#    응답: {"timestamp":"2025-08-13T16:03:54.271909","status":400,"code":"0004","message":"잘못된 파라미터 요청입니다.","url":"http://localhost:8080/crawling/naver-places","method":"POST","detailedErrors":[{"location":"contact","message":"공백일 수 없습니다"}]}
#
# [134/142] 처리 중...
# ✅ 성공: 등촌샤브칼국수 언주점
#
# [135/142] 처리 중...
# ✅ 성공: 제주몬트락 수서직영점
#
# [136/142] 처리 중...
# ❌ 실패: 식스나잇 - Status: 400
#    응답: {"timestamp":"2025-08-13T16:03:55.804318","status":400,"code":"0004","message":"잘못된 파라미터 요청입니다.","url":"http://localhost:8080/crawling/naver-places","method":"POST","detailedErrors":[{"location":"contact","message":"공백일 수 없습니다"}]}
#
# [137/142] 처리 중...
# ✅ 성공: 스시도
#
# [138/142] 처리 중...
# ✅ 성공: 김치옥 대치점
#
# [139/142] 처리 중...
# ✅ 성공: 이복희해장 선릉본점
#
# [140/142] 처리 중...
# ✅ 성공: 갓덴스시 강남점
#
# [141/142] 처리 중...
# ✅ 성공: 오징어세상 삼성점
#
# [142/142] 처리 중...
# ⚠️  스킵: 떡도리탕 강남본점 - 메뉴 정보 없음
#
# ==================================================
# 📈 전송 완료!
# ✅ 성공: 121개
# ❌ 실패: 4개
# 📊 성공률: 96.8%
#
# 🎉 모든 처리가 완료되었습니다!
# 📋 전체 실행을 원하시면 위의 main() 주석을 해제하고 실행하세요.
# 📊 현재 JSON 파일: ./naver_restaurants_20250813_153837.json
# 🎯 API 엔드포인트: http://localhost:8080/crawling/naver-places
